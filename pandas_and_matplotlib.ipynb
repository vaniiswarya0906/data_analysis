# %%
import pandas as pd
#importing pandas library into program

# %%
a=['daakshinya','geetha','vani iswarya','sri','mahi']
r=pd.Series(a,index=[16,29,41,46,23]) #Series function used to allocate the given element to existing element.
print(r)
# Out:
# 16      daakshinya
# 29          geetha
# 41    vani iswarya
# 46             sri
# 23            mahi
# dtype: object

# %%
a=pd.read_csv("/content/email_spam.csv")#loading csv dataset into program.
print(a)
b=pd.read_csv("/content/num.txt", sep=" ")#loading txt dataset using read_csv function.sep is used to seperate the elements in dataset.
print(b)
print(a.loc[1])
print(a.loc[1:3])#loc function represents the specific rows and columns
a.head(5)#first five rows are displayed from dataset
a.shape
s=a.tail(10)#last 10 rows of the dataset is displayed
s.to_csv("s.csv")#used save a new csv file
print(s)
# Out:
#                                                 title  \
# 0                           ?? the secrets to SUCCESS
# 1                     ?? You Earned 500 GCLoot Points
# 2                          ?? Your GitHub launch code
# 3   [The Virtual Reward Center] Re: ** Clarifications
# 4   10-1 MLB Expert Inside, Plus Everything You Ne...
# ..                                                ...
# 79  Your application for the position of  Child Pr...
# 80     Your Kilimall Account is Ready - Shopping Now!
# 81  Your Steam account: Access from new web or mob...
# 82                 Your uploaded document is rejected
# 83   You've Earned a Reward from Bard Explorers India
#
#                                                  text      type
# 0   Hi James,\n\nHave you claim your complimentary...      spam
# 1   \nalt_text\nCongratulations, you just earned\n...  not spam
# 2   Here's your GitHub launch code, @Mortyj420!\n ...  not spam
# ...

# %%
a.shape#shape is used to rows and columns of the dataset
s=a.tail(10)
s.to_csv("s.csv")
print(s)
print(s.groupby(['text'])['type'].count())#groupby is used to print specific columns, count function represents the number
# Out:
#                                                 title  \
# 74                          Yes- it is a numbers game
# 75  You applied to job post Translation_ISAAC_Acce...
# 76        Your Account Was Accessed From a New Device
# 77        Your Account Was Accessed From a New Device
# 78  Your Amazon.com order of "Nike Youth Dunk Low ...
# 79  Your application for the position of  Child Pr...
# 80     Your Kilimall Account is Ready - Shopping Now!
# 81  Your Steam account: Access from new web or mob...
# 82                 Your uploaded document is rejected
# 83   You've Earned a Reward from Bard Explorers India
#
#                                                  text      type
# 74  Hey Prachanda,\n \nToday's video... To build y...      spam
# 75  Hello there!\n\nYou have started the applicati...  not spam
# 76  We noticed a new login\nHello ondiekijohn254@g...      spam
# 77  We noticed a new login\nHello ondiekijohn254@g...  not spam
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt#importing matplotlib library into the program
runs=np.array([100,20,91,78,89,25,34,19,9,10])#crating an array.
w=np.array([1,0,2,0,3,7,8,9,7,5])
plt.scatter(runs,w,color='orange')#scatter function used to represent the plot in as no connection graph
plt.title('IndvsAus_score')#title function used to represent the title of the plot
plt.show()#show function used to display the plot

# %%
df=pd.read_excel("/content/Historicalinvesttemp.xlsx")#read_excel is used to load the excel dataset.
print(df)
df=pd.read_excel("/content/Historicalinvesttemp.xlsx",sheet_name="Sheet2")#to display specific sheet in the dataset
print(df)
m=df['tbills'].mean()#to find mean of specific column
print(m)
df=df.drop_duplicates()#to remove duplicates
print(df)
df.tail(5)
df.shape
# Out:
#    Unnamed: 0                        Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0         NaN                               NaN        NaN        NaN
# 1         NaN                               NaN        NaN        NaN
# 2         NaN                               NaN        NaN        NaN
# 3         NaN                               NaN        NaN        NaN
# 4         NaN  Annual Returns on Investments in        NaN        NaN
# ..        ...                               ...        ...        ...
# 85       2007                            0.0549     0.0988     0.0466
# 86       2008                             -0.37     0.2587      0.016
# 87       2009                            0.2646     -0.149      0.001
# 88        NaN                            stocks     tbills      bonds
# 89   averages                               NaN        NaN        NaN
#
# [90 rows x 4 columns]
#     year   stock  tbills  tbonds
# 0   2005     abc  0.5000  0.6000
# 1   2006  0.4381  0.0308  0.0084
# ...

# %%
tigar=np.linspace(-2*np.pi,2*np.pi,50)#generate array of 200 values between -pi and pi
print(tigar)
plt.plot(tigar,np.sin(tigar),color='black')#SIN plt.plot(x,y,color,labels..)
plt.title("sin(x)")
plt.show()
# Out:
# [-6.28318531 -6.02672876 -5.77027222 -5.51381568 -5.25735913 -5.00090259
#  -4.74444605 -4.48798951 -4.23153296 -3.97507642 -3.71861988 -3.46216333
#  -3.20570679 -2.94925025 -2.6927937  -2.43633716 -2.17988062 -1.92342407
#  -1.66696753 -1.41051099 -1.15405444 -0.8975979  -0.64114136 -0.38468481
#  -0.12822827  0.12822827  0.38468481  0.64114136  0.8975979   1.15405444
#   1.41051099  1.66696753  1.92342407  2.17988062  2.43633716  2.6927937
#   2.94925025  3.20570679  3.46216333  3.71861988  3.97507642  4.23153296
#   4.48798951  4.74444605  5.00090259  5.25735913  5.51381568  5.77027222
#   6.02672876  6.28318531]

# %%
tigar=np.linspace(-3*np.pi,3*np.pi,100)#generate array of 100 values between -pi and pi
print(tigar)
plt.plot(tigar,np.sin(tigar),color='black')#SIN plt.plot(x,y,color,labels..)
plt.title("sin(x)")
plt.show()
tigar=np.linspace(-np.pi,np.pi,100)#generate array of 200 values between -pi and pi
print(tigar)
plt.plot(tigar,np.sin(tigar),color='black')#SIN plt.plot(x,y,color,labels..)
plt.title("sin(x)")
plt.show()
# Out:
# [-9.42477796 -9.23437841 -9.04397885 -8.8535793  -8.66317974 -8.47278019
#  -8.28238063 -8.09198108 -7.90158152 -7.71118197 -7.52078241 -7.33038286
#  -7.1399833  -6.94958375 -6.75918419 -6.56878464 -6.37838508 -6.18798553
#  -5.99758598 -5.80718642 -5.61678687 -5.42638731 -5.23598776 -5.0455882
#  -4.85518865 -4.66478909 -4.47438954 -4.28398998 -4.09359043 -3.90319087
#  -3.71279132 -3.52239176 -3.33199221 -3.14159265 -2.9511931  -2.76079354
#  -2.57039399 -2.37999443 -2.18959488 -1.99919533 -1.80879577 -1.61839622
#  -1.42799666 -1.23759711 -1.04719755 -0.856798   -0.66639844 -0.47599889
#  -0.28559933 -0.09519978  0.09519978  0.28559933  0.47599889  0.66639844
#   0.856798    1.04719755  1.23759711  1.42799666  1.61839622  1.80879577
#   1.99919533  2.18959488  2.37999443  2.57039399  2.76079354  2.9511931
#   3.14159265  3.33199221  3.52239176  3.71279132  3.90319087  4.09359043
#   4.28398998  4.47438954  4.66478909  4.85518865  5.0455882   5.23598776
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
overs=np.arange(5,50,5)
overs_a=np.arange(5,30,5)
runs_i=np.array([25,51,84,131,160,189,220,250,267])
runs_a=np.array([15,41,94,110,151])
wickets=np.array([12,32,96])
plt.subplot(2,1,1)#to create subplot of the original plotting
plt.plot(overs,runs_i,color='blue',label='India')
plt.plot(overs_a,runs_a,color='yellow',label='Australia')
plt.legend(loc='best')#to display the label
plt.show()

# %%
a=[230,560,780,127,128]
b=[200,160,270,127,400]
years=[1,2,3,4]
profit_a=[(a[i]-a[i-1]) for i in range(1,len(a))]
profit_b=[(b[i]-b[i-1]) for i in range(1,len(b))]
plt.subplot(2,1,2)
plt.plot(years,profit_a,color='hotpink',linewidth='3',label='CompanyA',marker='*',ms='15',mec='k')
plt.subplot(2,1,1)
plt.plot(years,profit_b,color='black',linestyle='dotted',label='CompanyB',marker='H')
plt.show()

# %%
a=np.array([25,60,5,10])
labe=["ML","Python","Pandas","Numpy"]
plt.pie(a,labels=labe,colors=['pink','yellow','green','tomato'],textprops={'fontsize':20})
plt.show()

# %%
a=np.array([25,60,5,10])
labe=["ML","Python","Pandas","Numpy"]
explo=[0,0,0.2,0]
plt.pie(a,labels=labe,explode=explo,startangle=90)
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

a=pd.read_csv("/content/drive/MyDrive/Temperature.txt",sep=" ")
print(a)
print("\n the average in 50 days is:")
avg=a['Temperature'].mean()
print(avg)
print("\nthe lowest temperature rcorded is:")
print(a['Temperature'].min())
print("\nthe highest temperature rcorded is:")
print(a['Temperature'].max())
day=0
for i in a['Temperature']:
  if(i>avg):
    day=day+1
print("\nnumber of days where the temperature exceeded threshold is:\n")
plt.plot(a['Days'],a['Temperature'],color='black')
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.show()
# Out:
#     Days  Temperature
# 0      1         35.5
# 1      2         40.2
# 2      3         36.9
# 3      4         38.5
# 4      5         32.5
# 5      6         29.4
# 6      7         27.8
# 7      8         26.8
# 8      9         24.3
# 9     10         21.9
# 10    11         18.6
# 11    12         20.6
# 12    13         25.9
# 13    14         28.9
# 14    15         29.2
# 15    16         31.5
# 16    17         35.9
# 17    18         34.2
# 18    19         35.7
# 19    20         36.9
# 20    21         40.9
# 21    22         41.8
# 22    23         42.6
# 23    24         43.5
# 24    25         45.9
# 25    26         36.2
# 26    27         39.4
# 27    28         36.8
# 28    29         35.4
# 29    30         33.8
# 30    31         32.1
# 31    32         31.8
# 32    33         30.5
# 33    34         29.7
# 34    35         28.4
# 35    36         26.8
# 36    37         25.8
# 37    38         24.9
# 38    39         23.8
# 39    40         22.9
# ...
